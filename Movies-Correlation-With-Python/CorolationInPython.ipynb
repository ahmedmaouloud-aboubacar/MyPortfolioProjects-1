# %%
# Import libraries

import pandas as pd
import seaborn as sbn
import numpy as np

import matplotlib
import matplotlib.pyplot as plt 
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(12,8) # Adjust the configuration of the plots we will create

# Read in the data 

df = pd.read_csv('E:\GitGithub\AnalystBuilder\Data Analyst Portfolio Projects\Correlation in Python\movies.csv')

# %%
# Lets look at the data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Let see if there is any missing data
for column in df.columns:
    percentMissing=np.mean(df[column].isnull())
    print('{} - {}%'.format(column,percentMissing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# Data Type for our columns
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Chage coulmn  data type
df['budget'] = df['budget'].fillna(0) 
df['budget']=df['budget'].astype('int64')
df['gross'] = df['gross'].fillna(0)
df['gross']=df['gross'].astype('int64')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Create correct Year column
yearcorrect=[]
countrycorrect=[]
for i in range(0,len(df['released'])):
    yearcorrect.append(0);countrycorrect.append('')
    splitreleased=df['released'].astype(str).str[0:][i].split()
    if len(splitreleased)>=3:
        yearcorrect[i]=splitreleased[2]
    if len(splitreleased)==4:
        countrycorrect[i]=splitreleased[3][1:-1]
    if len(splitreleased)==5:
        countrycorrect[i]=splitreleased[3][1:]+' '+splitreleased[4][0:-1]

df['yearcorrect'] = yearcorrect
df['countrycorrect'] = countrycorrect
del(yearcorrect);del(countrycorrect)

# %%
#Descending Order by column gross
df.sort_values(by=['gross'],inplace=False,ascending=False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century    NaN   Comedy  1989
# 7667                                   Tee em el    NaN   Horror  2020
#
#                                released  score      votes        director  \
# ...

# %%
pd.set_option('display.max_rows',10)

# %%
df.sort_values(by=['gross'],inplace=False,ascending=False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century    NaN   Comedy  1989
# 7667                                   Tee em el    NaN   Horror  2020
#
#                                released  score      votes        director  \
# ...

# %%
# Drop any duplicattes
df['company'].drop_duplicates().sort_values(ascending=False)
# Out:
# 7129                                thefyzz
# 5664                            micro_scope
# 6412               iDeal Partners Film Fund
# 4007                               i5 Films
# 6793                             i am OTHER
#                        ...
# 3748                     1+2 Seisaku Iinkai
# 3024                        .406 Production
# 7525    "Weathering With You" Film Partners
# 4345        "DIA" Productions GmbH & Co. KG
# 408                                     NaN
# Name: company, Length: 2386, dtype: object

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Scatter plot with budget vs gross
df=df.sort_values(by=['gross'],inplace=False,ascending=False)
plt.scatter(x=df['budget'],y=df['gross'])
plt.title('Budget vs Gross Earning')
plt.xlabel('Gross Earning')
plt.ylabel('Budget for Film')
plt.show()

# %%
# Plot the budget vs gross using seaborn
sbn.regplot(x='budget',y='gross',data=df,scatter_kws={"color":"red"},line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# Let's start looking at correlation
corelation_matrix=df.corr(method='pearson',numeric_only = True) # pearson, kendall,spearman
corelation_matrix
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.261900  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.632834  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.750157  0.269510
# gross    0.261900  0.186392  0.632834  0.750157  1.000000  0.245235
# runtime  0.120811  0.399451  0.309212  0.269510  0.245235  1.000000

# %%
# High correlation between budget and gross
# I was right
sbn.heatmap(corelation_matrix,annot=True)
plt.title('Relation Matrix for Numerique Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
# Look at Company an numerize
df_numereized=df.copy()
for column in df_numereized.columns:
    if(df_numereized[column].dtype == 'object'):
        df_numereized[column]=df_numereized[column].astype('category')
        df_numereized[column]=df_numereized[column].cat.codes
df_numereized.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       5      0  2009       696    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019       183    8.4   903000.0       162     743
# 3045  6896       5      6  1997       704    7.8  1100000.0      1155    1778
# 6663  5144       5      0  2015       698    7.8   876000.0      1125    2550
# 7244   536       5      0  2018       192    8.4   897000.0       162     743
#
#       star  country     budget       gross  company  runtime  yearcorrect  \
# 5445  2334       55  237000000  2847246203     2253    162.0           32
# 7445  2241       55  356000000  2797501328     1606    181.0           42
# 3045  1595       55  200000000  2201647264     2253    194.0           20
# 6663   524       55  245000000  2069521700     1540    138.0           38
# 7244  2241       55  321000000  2048359754     1606    149.0           41
#
#       countrycorrect
# 5445              55
# ...

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
corr_matrix=df_numereized.corr(method='pearson',numeric_only = True) # pearson, kendall,spearman
sbn.heatmap(corr_matrix,annot=True)
plt.title('Relation Matrix for Numerique Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
corr_matrix
# Out:
#                     name    rating     genre      year  released     score  \
# name            1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating         -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre           0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year            0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released       -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# ...                  ...       ...       ...       ...       ...       ...
# gross           0.006989 -0.095450 -0.234297  0.261900  0.000519  0.186392
# company         0.009211 -0.032943 -0.071067 -0.010431 -0.010474  0.001030
# runtime         0.010392  0.062145 -0.052711  0.120811  0.000868  0.399451
# yearcorrect     0.010071  0.008230 -0.078972  0.990063 -0.006411  0.103330
# countrycorrect -0.003473  0.018519 -0.092614 -0.086991 -0.035169 -0.088293
#
# ...

# %%
pd.set_option('display.max_rows',None)
corr_pairs=corr_matrix.unstack()
sorted_pairs=corr_pairs.sort_values()
sorted_pairs
# Out:
# genre           budget           -0.334021
# budget          genre            -0.334021
# genre           gross            -0.234297
# gross           genre            -0.234297
# genre           votes            -0.145307
# votes           genre            -0.145307
# score           country          -0.133348
# country         score            -0.133348
# gross           rating           -0.095450
# rating          gross            -0.095450
# yearcorrect     countrycorrect   -0.092684
# countrycorrect  yearcorrect      -0.092684
# genre           countrycorrect   -0.092614
# countrycorrect  genre            -0.092614
#                 score            -0.088293
# score           countrycorrect   -0.088293
# countrycorrect  year             -0.086991
# year            countrycorrect   -0.086991
# budget          rating           -0.081939
# rating          budget           -0.081939
# genre           year             -0.081261
# year            genre            -0.081261
# ...

# %%
# Show High corolation
Highcorcondition=(sorted_pairs > 0.5) & (sorted_pairs!= 1)
sorted_pairs[Highcorcondition ]
# Out:
# votes        gross          0.632834
# gross        votes          0.632834
# budget       gross          0.750157
# gross        budget         0.750157
# year         yearcorrect    0.990063
# yearcorrect  year           0.990063
# dtype: float64

# %%
# Votes and budget have the highest correlation to gross earnings
